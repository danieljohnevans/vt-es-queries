# %%
from elasticsearch import Elasticsearch
from pprint import pprint
from dotenv import load_dotenv
import os

load_dotenv()
es_url = os.getenv("ES_URL")
es_username = os.getenv("ES_USERNAME")
es_password = os.getenv("ES_PASSWORD")

# %%
es = Elasticsearch(
    es_url,
    basic_auth=(es_username, es_password)
)
index_name = "viral-texts"

# %%
def get_document_by_id(doc_id):
    try:
        response = es.get(index=index_name, id=doc_id)
        return response['_source']
    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
def search_documents(field_name, keyword, size=10):
    try:
        query = {
            "query": {
                "match": {
                    field_name: keyword
                }
            },
            "size": size
        }
        response = es.search(index=index_name, body=query)
        return response['hits']['hits']
    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
doc_id = "e0eDDZIBLCOFKfgZ6Tn7"
document = get_document_by_id(doc_id)
print("Document by ID:")
pprint(document)
# Out:
# Document by ID:
# {'batch': 'lu_blastoise_ver01',
#  'begin': 2103,
#  'boiler': False,
#  'city': 'Opelousas',
#  'cluster': 309240220972,
#  'collation': '4',
#  'corpus': 'ca',
#  'country': 'United States of America',
#  'coverage': 'http://dbpedia.org/resource/Opelousas%2C_Louisiana',
#  'date': '1872-01-13',
#  'dateRange': '1868/1878',
#  'day': '1872-01-13',
#  'daylag': 7,
#  'ed': '1',
#  'end': 2407,
#  'frame': '0016',
#  'group': '/lccn/sn86079077',
#  'id': 'https://tile.loc.gov/storage-services/service/ndnp/lu/batch_lu_blastoise_ver01/data/sn86079077/0029587613A/1872011301/1872011301_1.xml#pageModsBib3',
#  'issue': 'https://tile.loc.gov/storage-services/service/ndnp/lu/batch_lu_blastoise_ver01/data/sn86079077/0029587613A/1872011301/1872011301_1.xml',
#  'lang': 'fr,en',
#  'lat': '30.533527777777778',
#  'lon': '-92.0815',
#  'open': 'true',
#  'p1dpi': 0,
#  'p1h': 1653,
#  'p1height': 25248,
#  'p1id': 'https://tile.loc.gov/storage-services/service/ndnp/lu/batch_lu_blastoise_ver01/data/sn86079077/0029587613A/1872011301/0016.jp2',
#  'p1iiif': 'https://tile.loc.gov/image-services/iiif/service:ndnp:lu:batch_lu_blastoise_ver01:data:sn86079077:0029587613A:1872011301:0016',
#  'p1seq': 3,
#  'p1w': 2298,
#  'p1width': 18672,
#  'p1x': 789,
#  'p1y': 13563,
#  'page_access': 'https://www.loc.gov/resource/sn86079077/1872-01-13/ed-1/?sp=3',
#  'page_image': 'https://tile.loc.gov/image-services/iiif/service:ndnp:lu:batch_lu_blastoise_ver01:data:sn86079077:0029587613A:1872011301:0016/pct:4.2255784061696655,53.719106463878326,12.30719794344473,6.547053231939164/full/0/default.jpg',
#  'page_thumb': 'https://tile.loc.gov/image-services/iiif/service:ndnp:lu:batch_lu_blastoise_ver01:data:sn86079077:0029587613A:1872011301:0016/pct:4.2255784061696655,53.719106463878326,12.30719794344473,6.547053231939164/!80,100/0/default.jpg',
#  'pboiler': 0.0,
#  'placeOfPublication': 'Opelousas, La.',
#  'pos': 2,
#  'pp': 4,
#  'publisher': 'J.W. Jackson & J.M. Gale',
#  'ref': 0,
#  'region': 'EUSA',
#  'replabel': '',
#  'repnote': 'Present',
#  'sbegin': 30529,
#  'send': 30907,
#  'seq': 3,
#  'series': '/lccn/sn86079077',
#  'size': 2,
#  'source': 'The Opelousas journal.',
#  'sourceFile': '././0016.tif',
#  'sourceFrame': '0016',
#  'source_file': '/data/vt-clusters-20240711/worker_3/part-00165-70bb98fa-24d4-4912-9607-5f6853cc75bc-c000.json',
#  'src': 5051082660561595201,
#  'text': ', talked of thieves and\n'
#          'plunderers, a voice cried out: "-Yes,\n'
#          'yon d , how much have you\n'
#          'plundered !" When the vice presi\xad\n'
#          'dents were named a voice cried :\n'
#          '"Lay them on the table." When\n'
#          'Bnrcli, Cnstom House Republican,\n'
#          'spoke, some one said: "What!\n'
#          'that d d nigger a democrat ?\n'
#          'That\'s enough for roe." It i',
#  'topdiv': 'Louisiana',
#  'uid': 766152236834820333,
#  'url': 'https://www.loc.gov/resource/sn86079077/1872-01-13/ed-1/?sp=3',
#  'wdid': 'Q1154039'}

# %%
field_name = "text"  # replace with the field you want to search
keyword = "talked of thieves"  # replace with your keyword
search_results = search_documents(field_name, keyword)
print("Search Results:")
pprint(search_results)
# Out:
# Search Results:
# [{'_id': '1rnKDJIBLCOFKfgZIP8q',
#   '_index': 'viral-texts',
#   '_score': 21.238295,
#   '_source': {'batch': 'mohi_edwards_ver01',
#               'begin': 46777,
#               'boiler': False,
#               'city': 'Kansas City',
#               'cluster': 223339262878,
#               'collation': '8',
#               'corpus': 'ca',
#               'country': 'United States of America',
#               'coverage': 'http://dbpedia.org/resource/Kansas_City%2C_Missouri',
#               'date': '1896-09-04',
#               'dateRange': '1892/1897',
#               'day': '1896-09-04',
#               'daylag': 1,
#               'ed': '1',
#               'end': 46891,
#               'frame': '0156',
#               'group': '/lccn/sn84020062',
#               'id': 'https://tile.loc.gov/storage-services/service/ndnp/mohi/batch_mohi_edwards_ver01/data/sn86063624/00211109385/1896090401/1896090401_1.xml#pageModsBib4',
#               'issue': 'https://tile.loc.gov/storage-services/service/ndnp/mohi/batch_mohi_edwards_ver01/data/sn86063624/00211109385/1896090401/1896090401_1.xml',
#               'lang': 'en',
#               'lat': '39.05',
#               'lon': '-94.583333333333',
#               'open': 'true',
#               'p1dpi': 4,
#               'p1h': 504,
#               'p1height': 28632,
#               'p1id': 'https://tile.loc.gov/storage-services/service/ndnp/mohi/batch_mohi_edwards_ver01/data/sn86063624/00211109385/1896090401/0156.jp2',
#               'p1iiif': 'https://tile.loc.gov/image-services/iiif/service:ndnp:mohi:batch_mohi_edwards_ver01:data:sn86063624:00211109385:1896090401:0156',
#               'p1seq': 4,
#               'p1w': 2636,
#               'p1width': 21148,
#               'p1x': 17736,
#               'p1y': 15724,
#               'page_access': 'https://www.loc.gov/resource/sn86063624/1896-09-04/ed-1/?sp=4',
#               'page_image': 'https://tile.loc.gov/image-services/iiif/service:ndnp:mohi:batch_mohi_edwards_ver01:data:sn86063624:00211109385:1896090401:0156/pct:83.86608662757708,54.91757474154792,12.464535653489692,1.760268231349539/full/0/default.jpg',
#               'page_thumb': 'https://tile.loc.gov/image-services/iiif/service:ndnp:mohi:batch_mohi_edwards_ver01:data:sn86063624:00211109385:1896090401:0156/pct:83.86608662757708,54.91757474154792,12.464535653489692,1.760268231349539/!80,100/0/default.jpg',
#               'pboiler': 0.0,
#               'placeOfPublication': 'Kansas City, Mo.',
#               'pos': 3,
#               'pp': 8,
#               'publisher': 'Journal Co.',
#               'ref': 0,
#               'region': 'EUSA',
#               'repnote': 'Present',
#               'seq': 4,
#               'series': '/lccn/sn86063624',
#               'size': 2,
#               'source': 'Kansas City daily journal.',
#               'sourceFile': '/mnt/netapp01.iarchives.com/processing/jobq/root/projects/production/newspaper/SHSM/NDNP_08/Kansas_City_Daily_Journal/KDJ_18960816-18961115/ocr/0160.tif',
#               'sourceFrame': '0160',
#               'source_file': '/data/vt-clusters-20240711/worker_2/part-00161-70bb98fa-24d4-4912-9607-5f6853cc75bc-c000.json',
#               'text': 'ht.\n'
#                       'Horse thieves are operating; boldly in Ce\xad\n'
#                       'dar county, and a vigilance committee Is\n'
#                       'being seriously talked of.',
#               'topdiv': 'Missouri',
#               'uid': -3892010349105410657,
#               'url': 'https://www.loc.gov/resource/sn86063624/1896-09-04/ed-1/?sp=4',
#               'wdid': 'Q41819'}},
#  {'_id': '17nKDJIBLCOFKfgZIP8q',
#   '_index': 'viral-texts',
#   '_score': 21.179901,
#   '_source': {'batch': 'mohi_marmaduke_ver02',
#               'begin': 7137,
#               'boiler': False,
#               'city': 'Potosi',
#               'cluster': 223339262878,
#               'collation': '4',
#               'corpus': 'ca',
#               'country': 'United States of America',
#               'coverage': 'http://dbpedia.org/resource/Potosi%2C_Missouri',
#               'date': '1896-09-09',
#               'dateRange': '1894/1929',
#               'day': '1896-09-09',
#               'daylag': 7,
#               'ed': '1',
#               'end': 7254,
#               'frame': '0468',
#               'group': '/lccn/sn90061371',
#               'id': 'https://tile.loc.gov/storage-services/service/ndnp/mohi/batch_mohi_marmaduke_ver02/data/sn90061371/00294557179/1896090901/1896090901_1.xml#pageModsBib2',
#               'issue': 'https://tile.loc.gov/storage-services/service/ndnp/mohi/batch_mohi_marmaduke_ver02/data/sn90061371/00294557179/1896090901/1896090901_1.xml',
#               'lang': 'en',
#               'lat': '37.9378',
#               'lon': '-90.7819',
#               'open': 'true',
#               'p1dpi': 4,
#               'p1h': 700,
#               'p1height': 30536,
#               'p1id': 'https://tile.loc.gov/storage-services/service/ndnp/mohi/batch_mohi_marmaduke_ver02/data/sn90061371/00294557179/1896090901/0468.jp2',
#               'p1iiif': 'https://tile.loc.gov/image-services/iiif/service:ndnp:mohi:batch_mohi_marmaduke_ver02:data:sn90061371:00294557179:1896090901:0468',
#               'p1seq': 2,
#               'p1w': 2700,
#               'p1width': 23860,
#               'p1x': 5024,
#               'p1y': 7356,
#               'page_access': 'https://www.loc.gov/resource/sn90061371/1896-09-09/ed-1/?sp=2',
#               'page_image': 'https://tile.loc.gov/image-services/iiif/service:ndnp:mohi:batch_mohi_marmaduke_ver02:data:sn90061371:00294557179:1896090901:0468/pct:21.05616093880972,24.08959916164527,11.316010058675607,2.292376211684569/full/0/default.jpg',
#               'page_thumb': 'https://tile.loc.gov/image-services/iiif/service:ndnp:mohi:batch_mohi_marmaduke_ver02:data:sn90061371:00294557179:1896090901:0468/pct:21.05616093880972,24.08959916164527,11.316010058675607,2.292376211684569/!80,100/0/default.jpg',
#               'pboiler': 0.0,
#               'placeOfPublication': 'Potosi, Mo.',
#               'pos': 1,
#               'pp': 4,
#               'publisher': 'F.M. Deggendorf',
#               'ref': 0,
#               'region': 'EUSA',
#               'repnote': 'Present',
#               'sbegin': 46777,
#               'send': 46891,
#               'seq': 2,
#               'series': '/lccn/sn90061371',
#               'size': 2,
#               'source': 'Potosi journal.',
#               'sourceFile': '/mnt/192.168.101.196/data01/jobq/root/projects/production/newspaper/SHSM/SHSM_NDNP_2012/batch_marmaduke/TPJ_18940822-18980629/ocr/0466.tif',
#               'sourceFrame': '0466',
#               'source_file': '/data/vt-clusters-20240711/worker_2/part-00161-70bb98fa-24d4-4912-9607-5f6853cc75bc-c000.json',
#               'src': -3892010349105410657,
#               'text': ' Star.\n'
#                       'Hons: thieves are operating boldly\n'
#                       'in Cedar county, and a vigdance com\xad\n'
#                       'mittee is being s-eriously talked of.\n',
#               'topdiv': 'Missouri',
#               'uid': 5828921830568036842,
#               'url': 'https://www.loc.gov/resource/sn90061371/1896-09-09/ed-1/?sp=2',
#               'wdid': 'Q955174'}},
#  {'_id': 'pazHDJIBLCOFKfgZHS1_',
#   '_index': 'viral-texts',
#   '_score': 20.587639,
#   '_source': {'batch': 'khi_ingalls_ver02',
#               'begin': 28200,
#               'boiler': False,
#               'city': 'Wichita',
#               'cluster': 180390833651,
#               'collation': '8',
#               'corpus': 'ca',
#               'country': 'United States of America',
#               'coverage': 'http://dbpedia.org/resource/Wichita%2C_Kansas',
#               'date': '1892-05-03',
#               'dateRange': '1890/1906',
#               'day': '1892-05-03',
#               'daylag': 2,
#               'ed': '1',
#               'end': 28338,
#               'frame': '0408',
#               'group': '/lccn/sn83045705',
#               'id': 'https://tile.loc.gov/storage-services/service/ndnp/khi/batch_khi_ingalls_ver02/data/sn82014635/00237286741/1892050301/1892050301_1.xml#pageModsBib2',
#               'issue': 'https://tile.loc.gov/storage-services/service/ndnp/khi/batch_khi_ingalls_ver02/data/sn82014635/00237286741/1892050301/1892050301_1.xml',
#               'lang': 'en',
#               'lat': '37.688888888889',
#               'lon': '-97.336111111111',
#               'open': 'true',
#               'p1dpi': 3,
#               'p1h': 450,
#               'p1height': 27201,
#               'p1id': 'https://tile.loc.gov/storage-services/service/ndnp/khi/batch_khi_ingalls_ver02/data/sn82014635/00237286741/1892050301/0408.jp2',
#               'p1iiif': 'https://tile.loc.gov/image-services/iiif/service:ndnp:khi:batch_khi_ingalls_ver02:data:sn82014635:00237286741:1892050301:0408',
#               'p1seq': 2,
#               'p1w': 2499,
#               'p1width': 20028,
#               'p1x': 8451,
#               'p1y': 20967,
#               'page_access': 'https://www.loc.gov/resource/sn82014635/1892-05-03/ed-1/?sp=2',
#               'page_image': 'https://tile.loc.gov/image-services/iiif/service:ndnp:khi:batch_khi_ingalls_ver02:data:sn82014635:00237286741:1892050301:0408/pct:42.19592570401438,77.08172493658321,12.477531455961653,1.6543509429800376/full/0/default.jpg',
#               'page_thumb': 'https://tile.loc.gov/image-services/iiif/service:ndnp:khi:batch_khi_ingalls_ver02:data:sn82014635:00237286741:1892050301:0408/pct:42.19592570401438,77.08172493658321,12.477531455961653,1.6543509429800376/!80,100/0/default.jpg',
#               'pboiler': 0.0,
#               'placeOfPublication': 'Wichita, Kan.',
#               'pos': 1,
#               'pp': 8,
#               'publisher': 'M.M. Murdock & R.P. Murdock',
#               'ref': 0,
#               'region': 'WUSA',
#               'repnote': 'Present',
#               'sbegin': 10281,
#               'send': 10417,
#               'seq': 2,
#               'series': '/lccn/sn82014635',
#               'size': 17,
#               'source': 'The Wichita daily eagle.',
#               'sourceFile': '/mnt/lustre01.iarchives.com/lustre01/root/projects/production/newspaper/KHS/NDNP_2009/batch_ingalls/TWD_18920306-18920606/ocr/0409.tif',
#               'sourceFrame': '0409',
#               'source_file': '/data/vt-clusters-20240711/worker_1/part-00045-70bb98fa-24d4-4912-9607-5f6853cc75bc-c000.json',
#               'src': 3018259666951890226,
#               'text': '(\n'
#                       'associated me with her convicted thieves\n'
#                       "Atiil burglars I talked daily with them. '\n"
#                       'Their destination after tneir time\n'
#                       'prison was Americ',
#               'topdiv': 'Kansas',
#               'uid': 1880574827838906868,
#               'url': 'https://www.loc.gov/resource/sn82014635/1892-05-03/ed-1/?sp=2',
#               'wdid': 'Q49266'}},
#  {'_id': 'aBoSDZIBLCOFKfgZ4NI6',
#   '_index': 'viral-texts',
#   '_score': 20.159641,
#   '_source': {'batch': 'iahi_charizard_ver01',
#               'begin': 3459,
#               'boiler': False,
#               'city': 'Tipton',
#               'cluster': 309238717881,
#               'collation': '4',
#               'corpus': 'acdc',
#               'country': 'United States of America',
#               'coverage': 'http://dbpedia.org/resource/Tipton%2C_Iowa',
#               'date': '1864-01-07',
#               'dateRange': '1856/1962',
#               'day': '1864-01-07',
#               'daylag': 14,
#               'ed': '1',
#               'end': 3666,
#               'file': 'https://tile.loc.gov/storage-services/service/ndnp/iahi/batch_iahi_charizard_ver01/data/sn84027398/00279529406/1864010701/0923.jp2',
#               'frame': '0923',
#               'group': '/lccn/sn85049620',
#               'id': 'https://tile.loc.gov/storage-services/service/ndnp/iahi/batch_iahi_charizard_ver01/data/sn84027398/00279529406/1864010701/1864010701_1.xml#pageModsBib2',
#               'issue': 'https://tile.loc.gov/storage-services/service/ndnp/iahi/batch_iahi_charizard_ver01/data/sn84027398/00279529406/1864010701/1864010701_1.xml',
#               'lang': 'en',
#               'lat': '41.770555555556',
#               'lon': '-91.129166666667',
#               'open': 'true',
#               'p1dpi': 3,
#               'p1h': 861,
#               'p1height': 25017,
#               'p1id': 'https://tile.loc.gov/storage-services/service/ndnp/iahi/batch_iahi_charizard_ver01/data/sn84027398/00279529406/1864010701/0923.jp2',
#               'p1iiif': 'https://tile.loc.gov/image-services/iiif/service:ndnp:iahi:batch_iahi_charizard_ver01:data:sn84027398:00279529406:1864010701:0923',
#               'p1seq': 2,
#               'p1w': 2456,
#               'p1width': 17757,
#               'p1x': 4042,
#               'p1y': 8484,
#               'page_access': 'https://www.loc.gov/resource/sn84027398/1864-01-07/ed-1/?sp=2',
#               'page_image': 'https://tile.loc.gov/image-services/iiif/service:ndnp:iahi:batch_iahi_charizard_ver01:data:sn84027398:00279529406:1864010701:0923/pct:22.762854085712675,33.912939201343086,13.83116517429746,3.441659671423432/full/0/default.jpg',
#               'page_thumb': 'https://tile.loc.gov/image-services/iiif/service:ndnp:iahi:batch_iahi_charizard_ver01:data:sn84027398:00279529406:1864010701:0923/pct:22.762854085712675,33.912939201343086,13.83116517429746,3.441659671423432/!80,100/0/default.jpg',
#               'pboiler': 0.0,
#               'placeOfPublication': 'Tipton, Cedar Co., Iowa',
#               'pos': 1,
#               'pp': 4,
#               'publisher': 'Wells Spicer',
#               'ref': 0,
#               'region': 'EUSA',
#               'repnote': 'Present',
#               'sbegin': 4572,
#               'send': 4777,
#               'seq': 2,
#               'series': '/lccn/sn84027398',
#               'size': 10,
#               'source': 'The Tipton advertiser.',
#               'sourceFile': 'sn84027398/00279529406/1864010701/0923.tif',
#               'sourceFrame': '0923',
#               'source_file': '/data/vt-clusters-20240711/worker_3/part-00069-70bb98fa-24d4-4912-9607-5f6853cc75bc-c000.json',
#               'src': -1670727259554626112,
#               'text': '.\n'
#                       '--Indiana, especially the southern\n'
#                       'part of it, is at this time overrun with\n'
#                       'thieves and burglars to such an extent\n'
#                       'that the California remedy of a vigilance\n'
#                       'committec is beginning to be seriously\n'
#                       'talked of',
#               'topdiv': 'Iowa',
#               'uid': 8344237127652924099,
#               'url': 'https://www.loc.gov/resource/sn84027398/1864-01-07/ed-1/?sp=2',
#               'wdid': 'Q1925245'}},
#  {'_id': 'EWkVDpIBLCOFKfgZAaHs',
#   '_ignored': ['text.keyword'],
#   '_index': 'viral-texts',
#   '_score': 19.9392,
#   '_source': {'batch': 'mthi_lynx_ver01',
#               'begin': 60600,
#               'boiler': False,
#               'city': 'Deer Lodge',
#               'cluster': 77310811630,
#               'collation': '4',
#               'corpus': 'ca',
#               'country': 'United States of America',
#               'coverage': 'http://dbpedia.org/resource/Deer_Lodge%2C_Montana',
#               'date': '1878-05-10',
#               'dateRange': '1869/1897',
#               'day': '1878-05-10',
#               'daylag': 7,
#               'ed': '1',
#               'end': 61211,
#               'frame': '0288',
#               'group': '/lccn/sn84038125',
#               'id': 'https://tile.loc.gov/storage-services/service/ndnp/mthi/batch_mthi_lynx_ver01/data/sn84038125/00294554853/1878051001/1878051001_1.xml#pageModsBib2',
#               'issue': 'https://tile.loc.gov/storage-services/service/ndnp/mthi/batch_mthi_lynx_ver01/data/sn84038125/00294554853/1878051001/1878051001_1.xml',
#               'lang': 'en',
#               'lat': '46.396111111111',
#               'lon': '-112.73305555556',
#               'open': 'true',
#               'p1dpi': 0,
#               'p1h': 2298,
#               'p1height': 28608,
#               'p1id': 'https://tile.loc.gov/storage-services/service/ndnp/mthi/batch_mthi_lynx_ver01/data/sn84038125/00294554853/1878051001/0288.jp2',
#               'p1iiif': 'https://tile.loc.gov/image-services/iiif/service:ndnp:mthi:batch_mthi_lynx_ver01:data:sn84038125:00294554853:1878051001:0288',
#               'p1seq': 2,
#               'p1w': 2256,
#               'p1width': 20688,
#               'p1x': 18060,
#               'p1y': 23187,
#               'page_access': 'https://www.loc.gov/resource/sn84038125/1878-05-10/ed-1/?sp=2',
#               'page_image': 'https://tile.loc.gov/image-services/iiif/service:ndnp:mthi:batch_mthi_lynx_ver01:data:sn84038125:00294554853:1878051001:0288/pct:87.29698375870069,81.05075503355705,10.904872389791183,8.032718120805368/full/0/default.jpg',
#               'page_thumb': 'https://tile.loc.gov/image-services/iiif/service:ndnp:mthi:batch_mthi_lynx_ver01:data:sn84038125:00294554853:1878051001:0288/pct:87.29698375870069,81.05075503355705,10.904872389791183,8.032718120805368/!80,100/0/default.jpg',
#               'pboiler': 0.0,
#               'placeOfPublication': 'Deer Lodge, Mont.',
#               'pos': 1,
#               'pp': 4,
#               'publisher': 'J.H. Mills',
#               'ref': 0,
#               'region': 'WUSA',
#               'replabel': '',
#               'repnote': 'Present',
#               'sbegin': 1267,
#               'send': 1864,
#               'seq': 2,
#               'series': '/lccn/sn84038125',
#               'size': 3,
#               'source': 'The new North-west.',
#               'sourceFile': '././0288.tif',
#               'sourceFrame': '0288',
#               'source_file': '/data/vt-clusters-20240711/worker_3/part-00128-70bb98fa-24d4-4912-9607-5f6853cc75bc-c000.json',
#               'src': 2865574105506054904,
#               'text': ' of\n'
#                       'FORT FETTERMAN, wy., nMay 1.-()n the\n'
#                       'night of the 29th, ult., four masked men\n'
#                       'broke into the ranch of Johr It. Samith,\n'
#                       "near Fort McKinney, stole evelyt'ihtg .'f\n"
#                       'value in the house, and run off four hI,1rses\n'
#                       'and two mules. To-day a patty of twenty\n'
#                       'cavalrymen, under the famous scout, Frank\n'
#                       "Giouard, left Fort McKinn, y ,, s'.ur the\n"
#                       "country for the thieves. The reiad bet we '\n"
#                       'this poet and McKinney is so infested with\n'
#                       'organized bands of horse thieves that travel\n'
#                       'with horses or mules is almost impo.-ible.\n'
#                       'The thieves are iunning off ainrinal every\n'
#                       'opportanity. A vigilance corumittee is\n'
#                       'strong I) talked of',
#               'topdiv': 'Montana',
#               'uid': -1466556476843823714,
#               'url': 'https://www.loc.gov/resource/sn84038125/1878-05-10/ed-1/?sp=2',
#               'wdid': 'Q960518'}},
#  {'_id': 'D2kVDpIBLCOFKfgZAaHs',
#   '_ignored': ['text.keyword'],
#   '_index': 'viral-texts',
#   '_score': 19.909946,
#   '_source': {'altSource': '',
#               'begin': 1267,
#               'boiler': False,
#               'category': 'News',
#               'city': 'Jefferson',
#               'cluster': 77310811630,
#               'corpus': 'gale-us',
#               'country': 'United States of America',
#               'coverage': 'http://dbpedia.org/resource/Jefferson%2C_Colorado',
#               'date': '1878-05-02',
#               'dateRange': '1860/1879',
#               'day': '1878-05-02',
#               'daylag': 1,
#               'end': 1864,
#               'group': '/lccn/sn95073774',
#               'id': '/lccn/sn95073774/5DYN-1878-MAY02-001-004',
#               'issue': '/lccn/sn95073774/5DYN-1878-MAY02',
#               'lang': 'en',
#               'lat': '39.3775',
#               'lon': '-105.801',
#               'open': 'false',
#               'p1dpi': 0,
#               'p1h': 414,
#               'p1height': 7754,
#               'p1id': '5DYN-1878-MAY02-001',
#               'p1seq': 1,
#               'p1w': 627,
#               'p1width': 6179,
#               'p1x': 2152,
#               'p1y': 2433,
#               'pboiler': 0.0,
#               'placeOfPublication': 'Denver, Jefferson [Colo.]',
#               'publisher': 'News Print. Co.',
#               'ref': 0,
#               'region': 'EUSA',
#               'seq': 3,
#               'series': '/lccn/sn95073774',
#               'size': 3,
#               'source': 'Daily Rocky Mountain news.',
#               'source_file': '/data/vt-clusters-20240711/worker_3/part-00128-70bb98fa-24d4-4912-9607-5f6853cc75bc-c000.json',
#               'text': '.\n'
#                       'FOnT FETTERLM[AN, May 1.-On the night\n'
#                       'of the 29th four masked men broke into the\n'
#                       'ranebe of John R. Smith, near Fort McKin\xad\n'
#                       'ney, and stole everything of value in the\n'
#                       'house and run off four horses and two mules.\n'
#                       'To-day a party of twenty cavalry men, under\n'
#                       'the famous Scout Frank Grouard, left for\n'
#                       'Fort Fort McKinney to scour the country for\n'
#                       'thieves. The road between this post and Mc\xad\n'
#                       'Kinney is so infested with organized bands of\n'
#                       'horse thieves that travel with horses or mules\n'
#                       'is almost impossible, the thieves running off\n'
#                       'animals on every opportunity. A vigilance\n'
#                       'committee is strongly talked of',
#               'title': 'Western Topics',
#               'topdiv': 'Colorado',
#               'uid': 2865574105506054904,
#               'wdid': 'Q3176638'}},
#  {'_id': 'oWdPDZIBLCOFKfgZrEhu',
#   '_index': 'viral-texts',
#   '_score': 19.847994,
#   '_source': {'batch': 'whi_dorothy_ver01',
#               'begin': 17695,
#               'boiler': False,
#               'city': 'Watertown',
#               'cluster': 858995394125,
#               'collation': '8',
#               'corpus': 'ca',
#               'country': 'United States of America',
#               'coverage': 'http://dbpedia.org/resource/Watertown%2C_Wisconsin',
#               'date': '1887-07-20',
#               'dateRange': '1860/1906',
#               'day': '1887-07-20',
#               'daylag': 7,
#               'ed': '1',
#               'end': 17914,
#               'frame': '0106',
#               'group': '/lccn/sn85033295',
#               'id': 'https://tile.loc.gov/storage-services/service/ndnp/whi/batch_whi_dorothy_ver01/data/sn85033295/00279550079/1887072001/1887072001_1.xml#pageModsBib2',
#               'issue': 'https://tile.loc.gov/storage-services/service/ndnp/whi/batch_whi_dorothy_ver01/data/sn85033295/00279550079/1887072001/1887072001_1.xml',
#               'lang': 'en',
#               'lat': '43.2',
#               'lon': '-88.716666666667',
#               'open': 'true',
#               'p1dpi': 0,
#               'p1h': 1101,
#               'p1height': 32235,
#               'p1id': 'https://tile.loc.gov/storage-services/service/ndnp/whi/batch_whi_dorothy_ver01/data/sn85033295/00279550079/1887072001/0106.jp2',
#               'p1iiif': 'https://tile.loc.gov/image-services/iiif/service:ndnp:whi:batch_whi_dorothy_ver01:data:sn85033295:00279550079:1887072001:0106',
#               'p1seq': 2,
#               'p1w': 3198,
#               'p1width': 22998,
#               'p1x': 11745,
#               'p1y': 9222,
#               'page_access': 'https://www.loc.gov/resource/sn85033295/1887-07-20/ed-1/?sp=2',
#               'page_image': 'https://tile.loc.gov/image-services/iiif/service:ndnp:whi:batch_whi_dorothy_ver01:data:sn85033295:00279550079:1887072001:0106/pct:51.069658231150534,28.60865518845975,13.905557004956952,3.4155421126105163/full/0/default.jpg',
#               'page_thumb': 'https://tile.loc.gov/image-services/iiif/service:ndnp:whi:batch_whi_dorothy_ver01:data:sn85033295:00279550079:1887072001:0106/pct:51.069658231150534,28.60865518845975,13.905557004956952,3.4155421126105163/!80,100/0/default.jpg',
#               'pboiler': 0.0,
#               'placeOfPublication': 'Watertown, Wis.',
#               'pos': 1,
#               'pp': 8,
#               'publisher': 'J.W. Lawton',
#               'ref': 0,
#               'region': 'EUSA',
#               'replabel': '',
#               'repnote': 'Present',
#               'sbegin': 30354,
#               'send': 30613,
#               'seq': 2,
#               'series': '/lccn/sn85033295',
#               'size': 2,
#               'source': 'Watertown republican.',
#               'sourceFile': '././0106.tif',
#               'sourceFrame': '0106',
#               'source_file': '/data/vt-clusters-20240711/worker_3/part-00187-70bb98fa-24d4-4912-9607-5f6853cc75bc-c000.json',
#               'src': 1497687505281741665,
#               'text': ' bar\xad\n'
#                       'rels were the thieves.\n'
#                       'Samuel Hay was kill by Jacob Robin\xad\n'
#                       "son, a w'ealthy farmer living near Jeffer\n"
#                       'sonville, Ind. Lynching was talked of\n'
#                       'and Gov. Gray telegraphed the sheriff\n'
#                       'to secure the safety of the prisoner',
#               'topdiv': 'Wisconsin',
#               'uid': -5319867999200052836,
#               'url': 'https://www.loc.gov/resource/sn85033295/1887-07-20/ed-1/?sp=2',
#               'wdid': 'Q1207479'}},
#  {'_id': 'xV6IDJIBLCOFKfgZ3Uyu',
#   '_ignored': ['text.keyword'],
#   '_index': 'viral-texts',
#   '_score': 19.763477,
#   '_source': {'batch': 'vi_lure_ver01',
#               'begin': 19622,
#               'boiler': False,
#               'city': 'Staunton',
#               'cluster': 1108104688125,
#               'collation': '2',
#               'corpus': 'ca',
#               'country': 'United States of America',
#               'coverage': 'http://dbpedia.org/resource/Staunton%2C_Virginia',
#               'date': '1872-12-31',
#               'dateRange': '1849/1896',
#               'day': '1872-12-31',
#               'daylag': 7,
#               'ed': '1',
#               'end': 19879,
#               'frame': '0400',
#               'group': '/lccn/sn83026160',
#               'id': 'https://tile.loc.gov/storage-services/service/ndnp/vi/batch_vi_lure_ver01/data/sn84024718/00280762490/1872123101/1872123101_1.xml#pageModsBib2',
#               'issue': 'https://tile.loc.gov/storage-services/service/ndnp/vi/batch_vi_lure_ver01/data/sn84024718/00280762490/1872123101/1872123101_1.xml',
#               'lang': 'en',
#               'lat': '38.1581',
#               'lon': '-79.0764',
#               'open': 'true',
#               'p1dpi': 0,
#               'p1h': 28091,
#               'p1height': 30708,
#               'p1id': 'https://tile.loc.gov/storage-services/service/ndnp/vi/batch_vi_lure_ver01/data/sn84024718/00280762490/1872123101/0400.jp2',
#               'p1iiif': 'https://tile.loc.gov/image-services/iiif/service:ndnp:vi:batch_vi_lure_ver01:data:sn84024718:00280762490:1872123101:0400',
#               'p1seq': 2,
#               'p1w': 5849,
#               'p1width': 23433,
#               'p1x': 7186,
#               'p1y': 1696,
#               'page_access': 'https://www.loc.gov/resource/sn84024718/1872-12-31/ed-1/?sp=2',
#               'page_image': 'https://tile.loc.gov/image-services/iiif/service:ndnp:vi:batch_vi_lure_ver01:data:sn84024718:00280762490:1872123101:0400/pct:30.66615456834379,5.5229907515956755,24.960525754278155,91.47779080369936/full/0/default.jpg',
#               'page_thumb': 'https://tile.loc.gov/image-services/iiif/service:ndnp:vi:batch_vi_lure_ver01:data:sn84024718:00280762490:1872123101:0400/pct:30.66615456834379,5.5229907515956755,24.960525754278155,91.47779080369936/!80,100/0/default.jpg',
#               'pboiler': 0.0,
#               'placeOfPublication': 'Staunton, Va.',
#               'pos': 1,
#               'pp': 2,
#               'publisher': 'L. Waddell, J.A. Waddell',
#               'ref': 0,
#               'region': 'EUSA',
#               'replabel': '',
#               'repnote': 'Present',
#               'sbegin': 22536,
#               'send': 22766,
#               'seq': 2,
#               'series': '/lccn/sn84024718',
#               'size': 3,
#               'source': 'Staunton spectator.',
#               'sourceFile': '././0400.tif',
#               'sourceFrame': '0400',
#               'source_file': '/data/vt-clusters-20240711/worker_3/part-00147-70bb98fa-24d4-4912-9607-5f6853cc75bc-c000.json',
#               'src': 8103128300719529361,
#               'text': ' .\n'
#                       '_« . \n'
#                       'The Huntington Independent says: a uew rail- (\n'
#                       'road from White Sulphur through Pocahontas, i\n'
#                       'Randolph, Pendleton, Grant, Hardy and (\n'
#                       'Hampshire counties, is much talked of.\n'
#                       '1\n'
#                       '\n'
#                       'J. F. Rinker is new Postmaster at Leesburg.\n'
#                       'A band of thieves have settle',
#               'topdiv': 'Virginia',
#               'uid': -1093324558876497197,
#               'url': 'https://www.loc.gov/resource/sn84024718/1872-12-31/ed-1/?sp=2',
#               'wdid': 'Q502250'}},
#  {'_id': 'FjGvDZIBLCOFKfgZPfW7',
#   '_index': 'viral-texts',
#   '_score': 19.64886,
#   '_source': {'batch': 'mnhi_gonvick_ver01',
#               'begin': 33657,
#               'boiler': False,
#               'city': 'Saint Paul',
#               'cluster': 755914420000,
#               'collation': '8',
#               'corpus': 'ca',
#               'country': 'United States of America',
#               'coverage': 'http://dbpedia.org/resource/Saint_Paul%2C_Minnesota',
#               'date': '1892-05-26',
#               'dateRange': '1884/1896',
#               'day': '1892-05-26',
#               'daylag': 1,
#               'ed': '1',
#               'end': 33913,
#               'frame': '0253',
#               'group': '/lccn/sn83025287',
#               'id': 'https://tile.loc.gov/storage-services/service/ndnp/mnhi/batch_mnhi_gonvick_ver01/data/sn90059522/00206538648/1892052601/1892052601_1.xml#pageModsBib4',
#               'issue': 'https://tile.loc.gov/storage-services/service/ndnp/mnhi/batch_mnhi_gonvick_ver01/data/sn90059522/00206538648/1892052601/1892052601_1.xml',
#               'lang': 'en',
#               'lat': '44.944166666667',
#               'lon': '-93.093611111111',
#               'open': 'true',
#               'p1dpi': 0,
#               'p1h': 902,
#               'p1height': 27840,
#               'p1id': 'https://tile.loc.gov/storage-services/service/ndnp/mnhi/batch_mnhi_gonvick_ver01/data/sn90059522/00206538648/1892052601/0253.jp2',
#               'p1iiif': 'https://tile.loc.gov/image-services/iiif/service:ndnp:mnhi:batch_mnhi_gonvick_ver01:data:sn90059522:00206538648:1892052601:0253',
#               'p1seq': 4,
#               'p1w': 2310,
#               'p1width': 21249,
#               'p1x': 13243,
#               'p1y': 3123,
#               'page_access': 'https://www.loc.gov/resource/sn90059522/1892-05-26/ed-1/?sp=4',
#               'page_image': 'https://tile.loc.gov/image-services/iiif/service:ndnp:mnhi:batch_mnhi_gonvick_ver01:data:sn90059522:00206538648:1892052601:0253/pct:62.322932843898535,11.217672413793103,10.871099816461951,3.2399425287356323/full/0/default.jpg',
#               'page_thumb': 'https://tile.loc.gov/image-services/iiif/service:ndnp:mnhi:batch_mnhi_gonvick_ver01:data:sn90059522:00206538648:1892052601:0253/pct:62.322932843898535,11.217672413793103,10.871099816461951,3.2399425287356323/!80,100/0/default.jpg',
#               'pboiler': 0.0,
#               'placeOfPublication': 'Saint Paul, Minn.',
#               'pos': 3,
#               'pp': 8,
#               'publisher': 'St. Paul Globe Print. Co.',
#               'ref': 0,
#               'region': 'EUSA',
#               'replabel': '',
#               'repnote': 'Present',
#               'sbegin': 11642,
#               'send': 11845,
#               'seq': 4,
#               'series': '/lccn/sn90059522',
#               'size': 2,
#               'source': 'St. Paul daily globe.',
#               'sourceFile': '././0253.tif',
#               'sourceFrame': '0253',
#               'source_file': '/data/vt-clusters-20240711/worker_3/part-00184-70bb98fa-24d4-4912-9607-5f6853cc75bc-c000.json',
#               'src': -8246121241660015244,
#               'text': '.\n'
#                       'As the land of cattle thieves and\n'
#                       'women politicians Wyoming is gaining\n'
#                       'quite an interstate notoriety.- Philadel-\n'
#                       "hi a I'ress.\n"
#                       'Those Southern delegates are begin\xad\n'
#                       'ning to line up with the Alger column.\n'
#                       'Sherman is BEam talked of. Check!—\n'
#                       "Detroit Free I'res",
#               'topdiv': 'Minnesota',
#               'uid': -3034179864160330658,
#               'url': 'https://www.loc.gov/resource/sn90059522/1892-05-26/ed-1/?sp=4',
#               'wdid': 'Q28848'}},
#  {'_id': 'e1aHDJIBLCOFKfgZmtAc',
#   '_ignored': ['text.keyword'],
#   '_index': 'viral-texts',
#   '_score': 19.537218,
#   '_source': {'batch': 'dlc_basic_ver01',
#               'begin': 4839,
#               'boiler': False,
#               'city': 'New York City',
#               'cluster': 1082332360610,
#               'collation': '8',
#               'corpus': 'acdc',
#               'country': 'United States of America',
#               'coverage': 'http://dbpedia.org/resource/New_York_City',
#               'date': '1863-04-09',
#               'dateRange': '1842/1866',
#               'day': '1863-04-09',
#               'daylag': 1,
#               'ed': '1',
#               'end': 5099,
#               'file': 'https://tile.loc.gov/storage-services/service/ndnp/dlc/batch_dlc_basic_ver01/data/sn83030213/0020653073A/1863040901/0675.jp2',
#               'frame': '0675',
#               'group': '/lccn/sn83030212',
#               'id': 'https://tile.loc.gov/storage-services/service/ndnp/dlc/batch_dlc_basic_ver01/data/sn83030213/0020653073A/1863040901/1863040901_1.xml#pageModsBib4',
#               'issue': 'https://tile.loc.gov/storage-services/service/ndnp/dlc/batch_dlc_basic_ver01/data/sn83030213/0020653073A/1863040901/1863040901_1.xml',
#               'lang': 'en',
#               'lat': '40.7',
#               'lon': '-74',
#               'open': 'true',
#               'p1dpi': 0,
#               'p1h': 1104,
#               'p1height': 24120,
#               'p1id': 'https://tile.loc.gov/storage-services/service/ndnp/dlc/batch_dlc_basic_ver01/data/sn83030213/0020653073A/1863040901/0675.jp2',
#               'p1iiif': 'https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_basic_ver01:data:sn83030213:0020653073A:1863040901:0675',
#               'p1seq': 4,
#               'p1w': 2786,
#               'p1width': 16644,
#               'p1x': 225,
#               'p1y': 17777,
#               'page_access': 'https://www.loc.gov/resource/sn83030213/1863-04-09/ed-1/?sp=4',
#               'page_image': 'https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_basic_ver01:data:sn83030213:0020653073A:1863040901:0675/pct:1.3518385003604902,73.70232172470979,16.738764720019226,4.577114427860696/full/0/default.jpg',
#               'page_thumb': 'https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_basic_ver01:data:sn83030213:0020653073A:1863040901:0675/pct:1.3518385003604902,73.70232172470979,16.738764720019226,4.577114427860696/!80,100/0/default.jpg',
#               'pboiler': 0.0,
#               'placeOfPublication': 'New-York [N.Y.]',
#               'pos': 3,
#               'pp': 8,
#               'publisher': 'Greeley & McElrath',
#               'ref': 0,
#               'region': 'EUSA',
#               'repnote': 'Present',
#               'seq': 4,
#               'series': '/lccn/sn83030213',
#               'size': 3,
#               'source': 'New-York daily tribune.',
#               'sourceFile': '0675.tif',
#               'sourceFrame': '0675',
#               'source_file': '/data/vt-clusters-20240711/worker_3/part-00147-70bb98fa-24d4-4912-9607-5f6853cc75bc-c000.json',
#               'text': '.\n'
#                       'The battle of Somerset put a quietus on the\n'
#                       'grand invasion of Kentucky, so long talked of, and\n'
#                       'there are believed to be no Rebels in Kentucky ex-\n'
#                       "copt near Cumberland Gap, Humphrey Marshall's\n"
#                       'scattered forces in Carter County, and a few prowl-\n'
#                       'ing thieves.\n'
#                       '-',
#               'topdiv': 'New York',
#               'uid': -5879331295127626606,
#               'url': 'https://www.loc.gov/resource/sn83030213/1863-04-09/ed-1/?sp=4',
#               'wdid': 'Q60'}}]
